# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
stud=pd.read_csv("C:/Stanalysis pbl/modified_student_data_india.csv")

# %%
print('Total number of students:',len(stud))
# Out:
# Total number of students: 395

# %%
stud['G3'].describe()
# Out:
# count    395.000000
# mean      10.415190
# std        4.581443
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
stud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# ### Attributes for student data india modified_student_data_india.csv (Math course and English language course) dataset:
# - 1 school - student's school (binary: 'KV' - Kendriya Vidyalaya or 'DPS' - Delhi Public School)
# - 2 sex - student's sex (binary: 'F' - female or 'M' - male)
# - 3 age - student's age (numeric: from 15 to 22)
# - 4 address - student's home address type (binary: 'U' - urban or 'R' - rural)
# - 5 famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# - 6 Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# - 7 Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 - 5th to 9th grade, 3 - secondary education or 4 - higher education)
# - 8 Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2-5th to 9th grade, 3-secondary education or 4 - higher education)
# - 9 Mjob - mother's job (nominal: 'teacher', 'doctor','farmer','Goverment services' , 'homemaker' or 'other')
# - 10 Fjob - father's job (nominal: 'teacher', 'doctor','farmer','Goverment services' , 'homemaker' or 'other)
# - 11 reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# - 12 guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# - 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# - 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# - 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# - 16 schoolsup - extra educational support (binary: yes or no)
# - 17 famsup - family educational support (binary: yes or no)
# - 18 paid - extra paid classes within the course subject (Math or English) (binary: yes or no)
# - 19 activities - extra-curricular activities (binary: yes or no)
# - 20 nursery - attended nursery school (binary: yes or no)
# - 21 higher - wants to take higher education (binary: yes or no)
# - 22 internet - Internet access at home (binary: yes or no)
# - 23 romantic - with a romantic relationship (binary: yes or no)
# - 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# - 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# - 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# - 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# - 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# - 29 health - current health status (numeric: from 1 - very bad to 5 - very good)
# - 30 absences - number of school absences (numeric: from 0 to 93)
#
# ### these grades are related with the course subject, Math or English:
# - 31 G1 - first period grade (numeric: from 0 to 20)
# - 31 G2 - second period grade (numeric: from 0 to 20)
# - 32 G3 - final grade (numeric: from 0 to 20, output target)

# %%
stud.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
stud.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
stud.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu       Mjob  \
# 0     KV   F   18    City     GT3       A     4     4  Homemaker
# 1     KV   F   17    City     GT3       T     1     1  Homemaker
# 2     KV   F   15    City     LE3       T     1     1  Homemaker
# 3     KV   F   15    City     GT3       T     4     2     Doctor
# 4     KV   F   16    City     GT3       T     3     3     Farmer
#
#                  Fjob  ... famrel freetime  goout  Dalc  Walc health absences  \
# 0             Teacher  ...      4        3      4     1     1      3        6
# 1              Farmer  ...      5        3      3     1     1      3        4
# 2              Farmer  ...      4        3      2     2     3      3       10
# 3  Government Service  ...      3        2      2     1     1      5        2
# 4              Farmer  ...      4        3      2     1     2      5        4
#
#    G1  G2  G3
# 0   5   6   6
# 1   5   5   6
# 2   7   8  10
# 3  15  14  15
# 4   6  10  10
#
# ...

# %%
stud.tail()
# Out:
#     school sex  age  address famsize Pstatus  Medu  Fedu                Mjob  \
# 390    DPS   M   20     City     LE3       A     2     2  Government Service
# 391    DPS   M   17     City     LE3       T     3     1  Government Service
# 392    DPS   M   21  Village     GT3       T     1     1              Farmer
# 393    DPS   M   18  Village     LE3       T     3     2  Government Service
# 394    DPS   M   19     City     LE3       T     1     1              Farmer
#
#                    Fjob  ... famrel freetime  goout  Dalc  Walc health  \
# 390  Government Service  ...      5        5      4     4     5      4
# 391  Government Service  ...      2        4      5     3     4      2
# 392              Farmer  ...      5        5      3     3     3      3
# 393              Farmer  ...      4        4      1     3     4      5
# 394           Homemaker  ...      3        2      3     3     3      5
#
#     absences  G1  G2  G3
# 390       11   9   9   9
# ...

# %%
stud.isnull().any()
# Out:
# school        False
# sex           False
# age           False
# address       False
# famsize       False
# Pstatus       False
# Medu          False
# Fedu          False
# Mjob          False
# Fjob          False
# reason        False
# guardian      False
# traveltime    False
# studytime     False
# failures      False
# schoolsup     False
# famsup        False
# paid          False
# activities    False
# nursery       False
# higher        False
# internet      False
# romantic      False
# famrel        False
# freetime      False
# goout         False
# Dalc          False
# Walc          False
# health        False
# absences      False
# G1            False
# G2            False
# G3            False
# dtype: bool

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
print(stud.head())
print(stud.dtypes)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu       Mjob  \
# 0     KV   F   18    City     GT3       A     4     4  Homemaker
# 1     KV   F   17    City     GT3       T     1     1  Homemaker
# 2     KV   F   15    City     LE3       T     1     1  Homemaker
# 3     KV   F   15    City     GT3       T     4     2     Doctor
# 4     KV   F   16    City     GT3       T     3     3     Farmer
#
#                  Fjob  ... famrel freetime  goout  Dalc  Walc health absences  \
# 0             Teacher  ...      4        3      4     1     1      3        6
# 1              Farmer  ...      5        3      3     1     1      3        4
# 2              Farmer  ...      4        3      2     2     3      3       10
# 3  Government Service  ...      3        2      2     1     1      5        2
# 4              Farmer  ...      4        3      2     1     2      5        4
#
#    G1  G2  G3
# 0   5   6   6
# 1   5   5   6
# 2   7   8  10
# 3  15  14  15
# 4   6  10  10
#
# ...

# %%
import pandas as pd
import cufflinks as cf
import plotly.io as pio

cf.go_offline()  
pio.renderers.default = 'notebook'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
print(stud[['age', 'G3']].isna().sum())  # Check for missing values
print(stud[['age', 'G3']].replace([np.inf, -np.inf], np.nan).isna().sum())  # Check for infinite values
# Out:
# age    0
# G3     0
# dtype: int64
# age    0
# G3     0
# dtype: int64

# %%
stud = stud.dropna(subset=['age', 'G3'])
stud = stud.replace([np.inf, -np.inf], np.nan).dropna(subset=['age', 'G3'])

# %%
import plotly.io as pio
pio.renderers.default = 'browser'

# %%
import plotly.graph_objects as go


fig = go.Figure()


for column in ['G3', 'failures', 'Medu', 'higher', 'age', 'Fedu', 'goout', 'romantic', 'reason']:
    fig.add_trace(go.Scatter(x=stud.index, y=stud[column], mode='lines', name=column))


fig.update_layout(title='Line Plot for Multiple Columns', xaxis_title='Index', yaxis_title='Values')


fig.show()

# %%
import plotly.graph_objects as go


fig = go.Figure(data=go.Scatter(x=stud['age'], y=stud['G3'], mode='markers'))
fig.update_layout(title='Scatter Plot of Age vs G3', xaxis_title='Age', yaxis_title='G3')

fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure()


for column in stud.columns:
    fig.add_trace(go.Box(y=stud[column], name=column))

# Update layout
fig.update_layout(title='Box Plot for Multiple Columns')

# Show the plot
fig.show()

# %%
import plotly.express as px


fig = px.histogram(stud, x='G3', nbins=100, title='Histogram of G3', color_discrete_sequence=['blue'])

# Show the plot
fig.show()

# %%
sns.heatmap(stud.isnull(),cmap="rainbow",yticklabels=False)  # To check any null values present in dataset pictorially
# Out:
# <Axes: >

# %%
sns.heatmap(stud.isnull(),cmap="viridis",yticklabels=False)
# Out:
# <Axes: >

# %% [markdown]
# - There are no null values in the given dataset

# %%
f_stud = len(stud[stud['sex'] == 'F'])    # Number of female students
print('Number of female students:',f_stud)
m_stud = len(stud[stud['sex'] == 'M'])    # Number of male students
print('Number of male students:',m_stud)
# Out:
# Number of female students: 208
# Number of male students: 187

# %%
sns.set_style('whitegrid')    # male & female student representaion on countplot
sns.countplot(x='sex',data=stud,palette='plasma')
# Out:
# C:\Users\junaid\AppData\Local\Temp\ipykernel_5348\375808890.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# - The gender distribution is pretty even.

# %%
b = sns.kdeplot(stud['age'])    # Kernel Density Estimations
b.axes.set_title('Ages of students')
b.set_xlabel('Age')
b.set_ylabel('Count')
plt.show()

# %%
b = sns.countplot(x='age',hue='sex', data=stud, palette='inferno')
b.axes.set_title('Number of Male & Female students in different age groups')
b.set_xlabel("Age")
b.set_ylabel("Count")
plt.show()

# %% [markdown]
# - The student age seems to be ranging from 15-19, where gender distribution is pretty even in each age group.
# - The age group above 19 may be outliers, year back students or droupouts.

# %%
u_stud = len(stud[stud['address'] == 'City'])    # Number of urban areas students
print('Number of city students:',u_stud)
r_stud = len(stud[stud['address'] == 'Village'])    # Number of rural areas students
print('Number of village students:',r_stud)
# Out:
# Number of city students: 307
# Number of village students: 88

# %%
sns.set_style('whitegrid')
sns.countplot(x='address',data=stud,palette='magma')
# Out:
# C:\Users\junaid\AppData\Local\Temp\ipykernel_5348\1056303686.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='address', ylabel='count'>

# %% [markdown]
# - Approximately 77.72% students come from urban region and 22.28% from rural region.

# %%
sns.countplot(x='address',hue='G3',data=stud,palette='Oranges')
# Out:
# <Axes: xlabel='address', ylabel='count'>

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %% [markdown]
# ### 1. Does age affect final grade?

# %%
b= sns.boxplot(x='age', y='G3',data=stud,palette='gist_heat')
b.axes.set_title('Age vs Final Grade')
# Out:
# C:\Users\junaid\AppData\Local\Temp\ipykernel_5348\4011241504.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Text(0.5, 1.0, 'Age vs Final Grade')

# %% [markdown]
# - The above plot shows that the median grades of the three age groups(15,16,17) are similar. Note the skewness of age group 19. (may be due to sample size). Age group 20 seems to score highest grades among all.

# %%
b = sns.swarmplot(x='age', y='G3',hue='sex', data=stud,palette='PiYG',size=4,dodge=True)
b.axes.set_title('Does age affect final grade?')
# Out:
# Text(0.5, 1.0, 'Does age affect final grade?')

# %% [markdown]
# ## 2. Do urban students perform better than rural students?

# %%
sns.kdeplot(stud.loc[stud['address'] == 'City', 'G3'], label='Urban', fill = True)
sns.kdeplot(stud.loc[stud['address'] == 'Village', 'G3'], label='Rural', fill = True)
plt.title('Do urban students score higher than rural students?')
plt.xlabel('Grade')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# - The above graph clearly shows there is no significant difference between the grades based on location.

# %%
numeric_stud = stud.select_dtypes(include='number')


correlation_with_G3 = numeric_stud.corr()['G3'].sort_values()

print(correlation_with_G3)
# Out:
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# health       -0.061335
# Dalc         -0.054660
# Walc         -0.051939
# freetime      0.011307
# absences      0.034247
# famrel        0.051363
# studytime     0.097820
# Fedu          0.152457
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %% [markdown]
# ## Encoding categorical variables using LabelEncoder()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
stud.iloc[:,0]=le.fit_transform(stud.iloc[:,0])
stud.iloc[:,1]=le.fit_transform(stud.iloc[:,1])
stud.iloc[:,3]=le.fit_transform(stud.iloc[:,3])
stud.iloc[:,4]=le.fit_transform(stud.iloc[:,4])
stud.iloc[:,5]=le.fit_transform(stud.iloc[:,5])
stud.iloc[:,8]=le.fit_transform(stud.iloc[:,8])
stud.iloc[:,9]=le.fit_transform(stud.iloc[:,9])
stud.iloc[:,10]=le.fit_transform(stud.iloc[:,10])
stud.iloc[:,11]=le.fit_transform(stud.iloc[:,11])
stud.iloc[:,15]=le.fit_transform(stud.iloc[:,15])
stud.iloc[:,16]=le.fit_transform(stud.iloc[:,16])
stud.iloc[:,17]=le.fit_transform(stud.iloc[:,17])
stud.iloc[:,18]=le.fit_transform(stud.iloc[:,18])
stud.iloc[:,19]=le.fit_transform(stud.iloc[:,19])
stud.iloc[:,20]=le.fit_transform(stud.iloc[:,20])
stud.iloc[:,21]=le.fit_transform(stud.iloc[:,21])
stud.iloc[:,22]=le.fit_transform(stud.iloc[:,22])

# %%
stud.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu Mjob Fjob  ... famrel  \
# 0      1   0   18       0       0       0     4     4    3    4  ...      4
# 1      1   0   17       0       0       1     1     1    3    1  ...      5
# 2      1   0   15       0       1       1     1     1    3    1  ...      4
# 3      1   0   15       0       0       1     4     2    0    2  ...      3
# 4      1   0   16       0       0       1     3     3    1    1  ...      4
#
#   freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0        3      4     1     1      3        6   5   6   6
# 1        3      3     1     1      3        4   5   5   6
# 2        3      2     2     3      3       10   7   8  10
# 3        2      2     1     1      5        2  15  14  15
# 4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
stud.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu Mjob Fjob  ... famrel  \
# 390      0   1   20       0       1       0     2     2    2    2  ...      5
# 391      0   1   17       0       1       1     3     1    2    2  ...      2
# 392      0   1   21       1       0       1     1     1    1    1  ...      5
# 393      0   1   18       1       1       1     3     2    2    1  ...      4
# 394      0   1   19       0       1       1     1     1    1    3  ...      3
#
#     freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390        5      4     4     5      4       11   9   9   9
# 391        4      5     3     4      2        3  14  16  16
# 392        5      3     3     3      3        3  10   8   7
# 393        4      1     3     4      5        0  11  12  10
# 394        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
stud = stud.select_dtypes(include=['float64', 'int64'])
correlation_matrix = stud.corr()
print(correlation_matrix['G3'].sort_values())
# Out:
# failures     -0.360415
# age          -0.161579
# goout        -0.132791
# traveltime   -0.117142
# health       -0.061335
# Dalc         -0.054660
# Walc         -0.051939
# freetime      0.011307
# absences      0.034247
# famrel        0.051363
# studytime     0.097820
# Fedu          0.152457
# Medu          0.217147
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %%
stud = stud.drop(['G1', 'G2'], axis='columns')  # Only drop existing columns

# %% [markdown]
# - Even though G1 and G2, the period grades, are closely related to the final grade (G3), we’re leaving them out. Predicting G3 becomes tougher without those grades, but this approach is more insightful because it helps us uncover other factors that impact the final grade.

# %%
most_correlated = stud.corr().abs()['G3'].sort_values(ascending=False)

# Maintain the top 8 most correlation features with Grade
most_correlated = most_correlated[:9]
most_correlated
# Out:
# G3            1.000000
# failures      0.360415
# Medu          0.217147
# age           0.161579
# Fedu          0.152457
# goout         0.132791
# traveltime    0.117142
# studytime     0.097820
# health        0.061335
# Name: G3, dtype: float64

# %%
stud = stud.loc[:, most_correlated.index]
stud.head()
# Out:
#    G3  failures  Medu  age  Fedu  goout  traveltime  studytime  health
# 0   6         0     4   18     4      4           2          2       3
# 1   6         0     1   17     1      3           1          2       3
# 2  10         3     1   15     1      2           1          2       3
# 3  15         0     4   15     2      2           1          3       5
# 4  10         0     3   16     3      2           1          2       5

# %% [markdown]
# ### Failure Attribute

# %%
b = sns.swarmplot(x=stud['failures'],y=stud['G3'],hue=stud['failures'],palette='autumn')
b.axes.set_title('Previous Failures vs Final Grade(G3)')
# Out:
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 31.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# Text(0.5, 1.0, 'Previous Failures vs Final Grade(G3)')
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 44.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %% [markdown]
# **Observation :** Student with less previous failures usually score higher

# %%
# Calculate the combined family education score
fa_edu = stud['Fedu'] + stud['Medu']

# Create a categorical column 'fa_edu_cat' based on the combined education score
stud['fa_edu_cat'] = pd.cut(fa_edu, bins=[0, 2, 4, 6, 8, 10], labels=['Low', 'Moderate', 'Average', 'High', 'Very High'])

# %%
b = sns.swarmplot(x=fa_edu,y=stud['G3'],hue=stud['fa_edu_cat'],palette='summer')
b.axes.set_title('Family Education vs Final Grade(G3)')
# Out:
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 6.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# Text(0.5, 1.0, 'Family Education vs Final Grade(G3)')

# %% [markdown]
# **Observation :** Educated families result in higher grades

# %% [markdown]
# ### Wish to go for Higher Education Attribute

# %%
stud.columns = stud.columns.str.strip()  # Remove leading/trailing spaces

# %%
stud = pd.read_csv('C:\\Stanalysis pbl\\modified_student_data_india.csv')
b = sns.boxplot(x='higher', y='G3', data=stud,hue=stud['higher'], palette='binary')
b.axes.set_title('Higher Education vs Final Grade (G3)')
plt.show()

# %% [markdown]
# **Observation :** Students who wish to go for higher studies score more

# %% [markdown]
# ## Going Out with Friends Attribute

# %%
b = sns.countplot(x=stud['goout'],palette='OrRd')
b.axes.set_title('Go Out vs Final Grade(G3)')
# Out:
# C:\Users\junaid\AppData\Local\Temp\ipykernel_25052\3223993246.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Text(0.5, 1.0, 'Go Out vs Final Grade(G3)')

# %% [markdown]
# **Observation :** The students have an average score when it comes to going out with friends.

# %%
b = sns.stripplot(x=stud['goout'],y=stud['G3'],palette='autumn')
b.axes.set_title('Go Out vs Final Grade(G3)')
# Out:
# C:\Users\junaid\AppData\Local\Temp\ipykernel_25052\649981999.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Text(0.5, 1.0, 'Go Out vs Final Grade(G3)')

# %% [markdown]
# **Observation:** Students who frequently go out tend to have lower scores.

# %% [markdown]
# ### Romantic relationship Attribute

# %%
b = sns.swarmplot(x=stud['romantic'],y=stud['G3'],palette='YlOrBr')
b.axes.set_title('Romantic Relationship vs Final Grade(G3)')
# Out:
# C:\Users\junaid\AppData\Local\Temp\ipykernel_25052\1658897987.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Text(0.5, 1.0, 'Romantic Relationship vs Final Grade(G3)')
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %% [markdown]
# - Here romantic attribute with value 0 means no relationship and value with 1 means in relationship
#
# **Observation :** Students with no romantic relationship score higher

# %% [markdown]
# ### Reason Attribute

# %%
b = sns.countplot(x='reason',data=stud,palette='gist_rainbow')    # Reason to choose this school
b.axes.set_title('Reason vs Students Count')
# Out:
# C:\Users\junaid\AppData\Local\Temp\ipykernel_25052\4014169648.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Text(0.5, 1.0, 'Reason vs Students Count')

# %%
b = sns.swarmplot(x='reason', y='G3', data=stud,palette='gist_rainbow')
b.axes.set_title('Reason vs Final grade')
# Out:
# C:\Users\junaid\AppData\Local\Temp\ipykernel_25052\3673982490.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Text(0.5, 1.0, 'Reason vs Final grade')
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 6.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %% [markdown]
# **Observation:** The average scores of students are evenly distributed across the different categories of the "reason" attribute.

# %% [markdown]
# # Machine Learning Algorithms

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

# Splitting data into training/testing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, median_absolute_error

# Distributions
import scipy

# %%
# splitting the data into training and testing data (75% and 25%)
# we mention the random state to achieve the same split everytime we run the code
X_train, X_test, y_train, y_test = train_test_split(stud, stud['G3'], test_size = 0.25, random_state=42)

# %%
X_train.head()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu                Mjob  \
# 16      KV   F   16    City     GT3       T     4     4  Government Service
# 66      KV   M   15    City     GT3       A     4     4              Farmer
# 211     KV   M   17    City     LE3       T     4     4  Government Service
# 7       KV   F   17    City     GT3       A     4     4              Farmer
# 19      KV   M   16    City     LE3       T     4     3              Doctor
#
#                    Fjob  ... famrel freetime  goout  Dalc  Walc health  \
# 16   Government Service  ...      3        2      3     1     2      2
# 66   Government Service  ...      1        3      3     5     5      3
# 211              Farmer  ...      5        3      5     4     5      3
# 7               Teacher  ...      4        1      4     1     1      1
# 19               Farmer  ...      3        1      3     1     3      5
#
#     absences  G1  G2  G3
# 16         6  13  14  14
# 66         4  13  13  12
# ...

# %% [markdown]
# ## MAE - Mean Absolute Error & RMSE - Root Mean Square Error

# %%
# Calculate mae and rmse
def evaluate_predictions(predictions, true):
    mae = np.mean(abs(predictions - true))
    rmse = np.sqrt(np.mean((predictions - true) ** 2))

    return mae, rmse

# %%
# find the median
median_pred = X_train['G3'].median()

# create a list with all values as median
median_preds = [median_pred for _ in range(len(X_test))]

# store the true G3 values for passing into the function
true = X_test['G3']

# %%
# Display the naive baseline metrics
mb_mae, mb_rmse = evaluate_predictions(median_preds, true)
print('Median Baseline  MAE: {:.4f}'.format(mb_mae))
print('Median Baseline RMSE: {:.4f}'.format(mb_rmse))
# Out:
# Median Baseline  MAE: 3.7879
# Median Baseline RMSE: 4.8252

# %%
def evaluate(X_train, X_test, y_train, y_test):
    # Names of models
    model_name_list = ['Linear Regression', 'ElasticNet Regression',
                      'Random Forest', 'Extra Trees', 'SVM',
                       'Gradient Boosted', 'Baseline']
    X_train = X_train.drop('G3', axis='columns')
    X_test = X_test.drop('G3', axis='columns')
    
    # Instantiate the models
    model1 = LinearRegression()
    model2 = ElasticNet(alpha=1.0, l1_ratio=0.5)
    model3 = RandomForestRegressor(n_estimators=100)
    model4 = ExtraTreesRegressor(n_estimators=100)
    model5 = SVR(kernel='rbf', degree=3, C=1.0, gamma='auto')
    model6 = GradientBoostingRegressor(n_estimators=50)
    
    # Dataframe for results
    results = pd.DataFrame(columns=['mae', 'rmse'], index = model_name_list)
    
    # Train and predict with each model
    for i, model in enumerate([model1, model2, model3, model4, model5, model6]):
        model.fit(X_train, y_train)
        predictions = model.predict(X_test)
        
        # Metrics
        mae = np.mean(abs(predictions - y_test))
        rmse = np.sqrt(np.mean((predictions - y_test) ** 2))
        
        # Insert results into the dataframe
        model_name = model_name_list[i]
        results.loc[model_name, :] = [mae, rmse]
    
    # Median Value Baseline Metrics
    baseline = np.median(y_train)
    baseline_mae = np.mean(abs(baseline - y_test))
    baseline_rmse = np.sqrt(np.mean((baseline - y_test) ** 2))
    
    results.loc['Baseline', :] = [baseline_mae, baseline_rmse]
    
    return results

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for column in non_numeric_columns:
    X_train[column] = le.fit_transform(X_train[column])
    X_test[column] = le.transform(X_test[column])

# %%
X_train = pd.get_dummies(X_train, columns=non_numeric_columns, drop_first=True)
X_test = pd.get_dummies(X_test, columns=non_numeric_columns, drop_first=True)

# Ensure both train and test have the same columns
X_train, X_test = X_train.align(X_test, join='left', axis=1, fill_value=0)

# %%
results = evaluate(X_train, X_test, y_train, y_test)
results
# Out:
#                             mae      rmse
# Linear Regression      1.483801  2.245588
# ElasticNet Regression  1.226473  2.060571
# Random Forest          1.069495  1.741892
# Extra Trees             1.24303  2.016973
# SVM                    1.629656  2.439602
# Gradient Boosted       1.064372  1.736413
# Baseline               3.787879  4.825228

# %%
plt.figure(figsize=(12, 7))

# Root mean squared error
ax =  plt.subplot(1, 2, 1)
results.sort_values('mae', ascending = True).plot.bar(y = 'mae', color = 'violet', ax = ax)
plt.title('Model Mean Absolute Error') 
plt.ylabel('MAE')

# Median absolute percentage error
ax = plt.subplot(1, 2, 2)
results.sort_values('rmse', ascending = True).plot.bar(y = 'rmse', color = 'pink', ax = ax)
plt.title('Model Root Mean Squared Error') 
plt.ylabel('RMSE')

plt.show()

# %% [markdown]
# Conclusion: As we see both Model Mean Absolute Error & Model Root Mean Squared Error that the linear regression is performing the best in both cases

# %% [markdown]
# # Predictions Using Various Models

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Step 1: Load the dataset
stud = pd.read_csv("C:/Stanalysis pbl/modified_student_data_india.csv")

# Step 2: Identify categorical columns
categorical_cols = stud.select_dtypes(include=['object']).columns
print("Categorical columns:", categorical_cols)

# Step 3: One-hot encode categorical columns
stud = pd.get_dummies(stud, columns=categorical_cols, drop_first=True)

# Step 4: Splitting data into features and target variable
X = stud.drop(columns='G3')  # Features
y = stud['G3']                # Target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Step 3: Function to calculate MAE and RMSE
def evaluate_predictions(predictions, true):
    mae = np.mean(abs(predictions - true))
    rmse = np.sqrt(np.mean((predictions - true) ** 2))
    return mae, rmse

# Create a baseline using the median of the training set
median_pred = y_train.median()
median_preds = [median_pred] * len(y_test)

# Display the naive baseline metrics
mb_mae, mb_rmse = evaluate_predictions(median_preds, y_test)
print('Median Baseline  MAE: {:.4f}'.format(mb_mae))
print('Median Baseline RMSE: {:.4f}'.format(mb_rmse))

# Step 4: Evaluate models
def evaluate(X_train, X_test, y_train, y_test):
    model_name_list = ['Linear Regression', 'ElasticNet Regression',
                       'Random Forest', 'Extra Trees', 'SVM', 'Gradient Boosted', 'Baseline']
    
    # Instantiate the models
    models = [
        LinearRegression(),
        ElasticNet(alpha=1.0, l1_ratio=0.5),
        RandomForestRegressor(n_estimators=100),
        ExtraTreesRegressor(n_estimators=100),
        SVR(kernel='rbf', degree=3, C=1.0, gamma='auto'),
        GradientBoostingRegressor(n_estimators=50)
    ]
    
    # Dataframe for results
    results = pd.DataFrame(columns=['mae', 'rmse'], index=model_name_list)
    
    # Train and predict with each model
    for i, model in enumerate(models):
        model.fit(X_train, y_train)
        predictions = model.predict(X_test)
        
        # Calculate metrics
        mae = np.mean(abs(predictions - y_test))
        rmse = np.sqrt(np.mean((predictions - y_test) ** 2))
        
        # Insert results into the dataframe
        results.loc[model_name_list[i]] = [mae, rmse]
    
    # Median Value Baseline Metrics
    baseline = np.median(y_train)
    baseline_mae = np.mean(abs(baseline - y_test))
    baseline_rmse = np.sqrt(np.mean((baseline - y_test) ** 2))
    results.loc['Baseline'] = [baseline_mae, baseline_rmse]
    
    return results

# Call the evaluate function and display results
results = evaluate(X_train, X_test, y_train, y_test)
print("Model Evaluation Results:")
print(results)

# Step 5: Make predictions about students scoring above average
# Calculate the average score
average_score = stud['G3'].mean()

# Use the best-performing model to predict outcomes (for example, Random Forest)
best_model = RandomForestRegressor(n_estimators=100)
best_model.fit(X, y)  # Fit on the entire dataset

# Get predictions for all students
predictions = best_model.predict(X)

# Add predictions to the DataFrame
stud['Predicted_G3'] = predictions

# Step 6: Predict Pass/Fail Outcomes
# Assuming passing score is greater than 10
passing_score = 10
stud['Pass/Fail_Prediction'] = np.where(stud['Predicted_G3'] > passing_score, 'Pass', 'Fail')

# Step 7: Display predictions for each student with pass/fail prediction
print("\nPredictions for each student:")
print(stud[['G3', 'Predicted_G3', 'Pass/Fail_Prediction', 'school_KV']])

# Step 8: Analyze pass/fail ratio based on school
pass_fail_summary = stud.groupby('school_KV')['Pass/Fail_Prediction'].value_counts().unstack(fill_value=0)

# Calculate pass/fail ratios
pass_fail_summary['Pass/Fail_Ratio'] = pass_fail_summary['Pass'] / (pass_fail_summary['Fail'] + 1e-5)  # Added small value to avoid division by zero

# Display pass/fail ratios
print("\nPass/Fail Ratio by School:")
print(pass_fail_summary[['Pass', 'Fail', 'Pass/Fail_Ratio']])
# Out:
# Categorical columns: Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')
# Median Baseline  MAE: 3.7879
# Median Baseline RMSE: 4.8252
# Model Evaluation Results:
#                             mae      rmse
# Linear Regression      1.483801  2.245588
# ElasticNet Regression  1.226473  2.060571
# Random Forest          1.063535  1.710175
# Extra Trees            1.269899  2.030963
# SVM                    1.629656  2.439602
# Gradient Boosted       1.047594  1.715173
# Baseline               3.787879  4.825228
#
# Predictions for each student:
#      G3  Predicted_G3 Pass/Fail_Prediction  school_KV
# 0     6          6.17                 Fail       True
# 1     6          5.90                 Fail       True
# 2    10          9.09                 Fail       True
# ...
